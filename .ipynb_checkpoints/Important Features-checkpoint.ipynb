# %%
import pandas as pd
from sklearn.ensemble import ExtraTreesClassifier
from numpy import set_printoptions
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif

# %%
data = pd.read_csv('Feature Importance Sheet.csv')

# %%
data
# Out:
#                                         Features  Importance Factor
# 0               phone_type_accelerometer-x_slope              0.008
# 1               phone_type_accelerometer-y_slope              0.006
# 2               phone_type_accelerometer-z_slope              0.008
# 3             phone_type_accelerometer-x_maximum              0.064
# 4             phone_type_accelerometer-y_maximum              0.061
# 5             phone_type_accelerometer-z_maximum              0.056
# 6             phone_type_accelerometer-x_minimum              0.118
# 7             phone_type_accelerometer-y_minimum              0.063
# 8             phone_type_accelerometer-z_minimum              0.015
# 9   phone_type_accelerometer-x_standarddeviation              0.023
# 10  phone_type_accelerometer-y_standarddeviation              0.039
# 11  phone_type_accelerometer-z_standarddeviation              0.029
# 12           phone_type_accelerometer-x_variance              0.006
# 13           phone_type_accelerometer-y_variance              0.012
# 14           phone_type_accelerometer-z_variance              0.007
# 15               phone_type_accelerometer-x_mean              0.032
# 16               phone_type_accelerometer-y_mean              0.110
# 17               phone_type_accelerometer-z_mean              0.069
# 18                  phone_type_gyroscope-x_slope              0.006
# 19                  phone_type_gyroscope-y_slope              0.005
# 20                  phone_type_gyroscope-z_slope              0.007
# 21                phone_type_gyroscope-x_maximum              0.017
# 22                phone_type_gyroscope-y_maximum              0.008
# 23                phone_type_gyroscope-z_maximum              0.019
# 24                phone_type_gyroscope-x_minimum              0.014
# 25                phone_type_gyroscope-y_minimum              0.010
# 26                phone_type_gyroscope-z_minimum              0.010
# 27      phone_type_gyroscope-x_standarddeviation              0.029
# 28      phone_type_gyroscope-y_standarddeviation              0.018
# 29      phone_type_gyroscope-z_standarddeviation              0.040
# 30               phone_type_gyroscope-x_variance              0.024
# 31               phone_type_gyroscope-y_variance              0.015
# 32               phone_type_gyroscope-z_variance              0.020
# 33                   phone_type_gyroscope-x_mean              0.011
# 34                   phone_type_gyroscope-y_mean              0.010
# 35                   phone_type_gyroscope-z_mean              0.010

# %%
sort_by_importance = data.sort_values('Importance Factor',ascending=False)

# %%
print(sort_by_importance)
# Out:
#                                         Features  Importance Factor
# 6             phone_type_accelerometer-x_minimum              0.118
# 16               phone_type_accelerometer-y_mean              0.110
# 17               phone_type_accelerometer-z_mean              0.069
# 3             phone_type_accelerometer-x_maximum              0.064
# 7             phone_type_accelerometer-y_minimum              0.063
# 4             phone_type_accelerometer-y_maximum              0.061
# 5             phone_type_accelerometer-z_maximum              0.056
# 29      phone_type_gyroscope-z_standarddeviation              0.040
# 10  phone_type_accelerometer-y_standarddeviation              0.039
# 15               phone_type_accelerometer-x_mean              0.032
# 11  phone_type_accelerometer-z_standarddeviation              0.029
# 27      phone_type_gyroscope-x_standarddeviation              0.029
# 30               phone_type_gyroscope-x_variance              0.024
# 9   phone_type_accelerometer-x_standarddeviation              0.023
# 32               phone_type_gyroscope-z_variance              0.020
# 23                phone_type_gyroscope-z_maximum              0.019
# 28      phone_type_gyroscope-y_standarddeviation              0.018
# 21                phone_type_gyroscope-x_maximum              0.017
# 8             phone_type_accelerometer-z_minimum              0.015
# 31               phone_type_gyroscope-y_variance              0.015
# 24                phone_type_gyroscope-x_minimum              0.014
# 13           phone_type_accelerometer-y_variance              0.012
# 33                   phone_type_gyroscope-x_mean              0.011
# 25                phone_type_gyroscope-y_minimum              0.010
# 35                   phone_type_gyroscope-z_mean              0.010
# 34                   phone_type_gyroscope-y_mean              0.010
# 26                phone_type_gyroscope-z_minimum              0.010
# 0               phone_type_accelerometer-x_slope              0.008
# 22                phone_type_gyroscope-y_maximum              0.008
# 2               phone_type_accelerometer-z_slope              0.008
# 20                  phone_type_gyroscope-z_slope              0.007
# 14           phone_type_accelerometer-z_variance              0.007
# 1               phone_type_accelerometer-y_slope              0.006
# 12           phone_type_accelerometer-x_variance              0.006
# 18                  phone_type_gyroscope-x_slope              0.006
# 19                  phone_type_gyroscope-y_slope              0.005
